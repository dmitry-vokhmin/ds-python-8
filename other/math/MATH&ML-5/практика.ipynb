# %%
from sympy import Symbol, solveset, Eq, solve, diff, symbols
import numpy as np

x = Symbol('x')

# %%
f = -2*x**3 - 3*x**2 + 12*x - 4
y = f.diff(x)
solveset(Eq(y, 0), x)
# Out:
# {-2, 1}

# %%
y.subs(x, 2)
# Out:
# -24

# %%
v1 = [12, 6]
v2 = [6, 12]
A = np.array([v1, v2])
np.linalg.eig(A)
# Out:
# EigResult(eigenvalues=array([18.,  6.]), eigenvectors=array([[ 0.70710678, -0.70710678],
#        [ 0.70710678,  0.70710678]]))

# %%
y = Symbol('y')

f = 4*x**2 - 6*x*y - 34*x + 5*y**2 + 42*y + 7
f_x = f.diff(x)
f_y = f.diff(y)

eq1 = Eq(f_x, 0)
eq2 = Eq(f_y, 0)

sol = solve([eq1, eq2], [x, y])
sol
# Out:
# {x: 2, y: -3}

# %%
f = x**3 - 2*x*y - y**6

f_xx = f.diff(x, 2)
f_yy = f.diff(y, 2)
f_xy = diff(f, x, y)

print(f_xx)
print(f_yy)
print(f_xy)
# Out:
# 6*x
# -30*y**4
# -2

# %%
A = np.array([
    [6, -2],
    [-2, -30*2**4]
])
np.linalg.det(A)
# Out:
# np.float64(-2884.0000000000014)

# %%
f = x**3 + y**3 - 3*x*y
f_x = f.diff(x)
f_y = f.diff(y)

eq1 = Eq(f_x, 0)
eq2 = Eq(f_y, 0)

sol = solve([eq1, eq2], [x, y])
sol
# Out:
# [(0, 0),
#  (1, 1),
#  ((-1/2 - sqrt(3)*I/2)**2, -1/2 - sqrt(3)*I/2),
#  ((-1/2 + sqrt(3)*I/2)**2, -1/2 + sqrt(3)*I/2)]

# %%
f_xx = f.diff(x, 2)
f_yy = f.diff(y, 2)
f_xy = diff(f, x, y)

print(f_xx)
print(f_yy)
print(f_xy)
# Out:
# 6*x
# 6*y
# -3

# %%
import numpy as np

def func_rosen(x):
    r = np.sum(100*(x[1:]-x[:-1]**2)**2 + (1-x[:-1])**2, axis=0)
    return r

# %%
from scipy.optimize import minimize, least_squares
x1 = np.array([2.4, 1.5, 2.1, 0.7, 1.1])
result_point = minimize(func_rosen, x1, method='powell')
print(result_point.x)
# Out:
# [1. 1. 1. 1. 1.]

# %%
result_point = least_squares(func_rosen, x1)
print(result_point.x)
# Out:
# [0.93865173 0.88210868 0.776457   0.60278764 0.36076162]

# %%
x, y, lam = symbols('x y lam')

f = 4*x + 3*y + lam*(x**2 + y**2 - 1)
f_x = f.diff(x)
f_y = f.diff(y)
f_lam = f.diff(lam)

print(f_x)
print(f_y)
print(f_lam)
# Out:
# 2*lam*x + 4
# 2*lam*y + 3
# x**2 + y**2 - 1

# %%
sol = solve([f_x, f_y, f_lam], [x, y, lam])
sol
# Out:
# [(4/5, 3/5, -5/2), (-4/5, -3/5, 5/2)]

# %%
# Импортируем все необходимые функции из библиотеки SymPy
from sympy import init_printing, solve, symbols

# Подключаем аккуратный вывод формул
init_printing()

# Создаём переменные
x1, x2, x1_tilde, lambda1, lambda2 = symbols(
    "x_1 x_2 xtilde_2 \lambda_1 \lambda_2", real=True
)

# Пишем систему уравнений для переменных
dLdx1 = -x2 + lambda1 - lambda2
dLdx2 = -x1 + lambda1
dLdx1_tilde = 2 * lambda2 * x1_tilde
dLdlambda1 = x1 + x2 - 10
dLdlambda2 = -x1 + 6 + x1_tilde**2

# Решаем систему уравнений с помощью функции solve
solution = solve(
    [dLdx1, dLdx2, dLdx1_tilde, dLdlambda1, dLdlambda2],
    x1,
    x2,
    x1_tilde,
    lambda1,
    lambda2,
)

print(solution)
# Out:
# [(6, 4, 0, 6, 2)]

# %%
from numpy import gradient

f = np.array([8, 2, 8, 3, 5, 6, 5, 15])

gradient(f, 7)[7]
# Out:
# np.float64(1.4285714285714286)

# %%
f = -x**4 + 6*x**3 -4*x**2 + 80
y = f.diff(x)
solve(Eq(y, 0), x)
# Out:
# [0, 1/2, 4]

# %%
y.subs(x, 3)
# Out:
# 30

# %%
x, y, lam = symbols('x y lam')

f_init = x** 2 + 2*y**2
f = x**2 + 2*y**2 - lam*(x + y - 20)
f_x = f.diff(x)
f_y = f.diff(y)
f_lam = f.diff(lam)
sol = solve([f_x, f_y, f_lam], [x, y, lam])
f_init.subs({x: sol[x], y: sol[y]})
# Out:
# 800/3
